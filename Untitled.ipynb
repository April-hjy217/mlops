# %%
import pandas as pd

# %%
file = "data/raw/yellow_tripdata_2023-01.parquet"

# %%
df = pd.read_parquet(file)

# %%
df.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# 5         2  2023-01-01 00:50:34   2023-01-01 01:02:52              1.0
# 6         2  2023-01-01 00:09:22   2023-01-01 00:19:49              1.0
# 7         2  2023-01-01 00:27:12   2023-01-01 00:49:56              1.0
# 8         2  2023-01-01 00:21:44   2023-01-01 00:36:40              1.0
# 9         2  2023-01-01 00:39:42   2023-01-01 00:50:36              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# ...

# %%
print("Number of columns:", df.shape[1])
# Out:
# Number of columns: 19

# %%
# Compute duration in minutes
df["duration"] = (
    df["tpep_dropoff_datetime"] - df["tpep_pickup_datetime"]
).dt.total_seconds() / 60

# %%
# Get the standard deviation
std_duration = df["duration"].std()
print("Std of trip durations (min):", round(std_duration, 2))
# Out:
# Std of trip durations (min): 42.59

# %%
# Filter to [1, 60] minutes
orig_count = len(df)
df_filtered = df[(df.duration >= 1) & (df.duration <= 60)]
filtered_count = len(df_filtered)

# %%
fraction = filtered_count / orig_count
print("As percentage:", round(fraction * 100, 2), "%")
# Out:
# As percentage: 98.12 %

# %%
# Cast IDs to strings so DictVectorizer treats them as categories
df["PULocationID"] = df["PULocationID"].astype(str)
df["DOLocationID"] = df["DOLocationID"].astype(str)

# %%
# Turn into list of dicts
records = df[["PULocationID", "DOLocationID"]].to_dict(orient="records")

# %%
# Fit the vectorizer
from sklearn.feature_extraction import DictVectorizer
dv = DictVectorizer(sparse=False)
X = dv.fit_transform(records)

# %%
# Check dimensionality
print("Feature matrix shape:", X.shape)   
print("Number of one-hot columns:", X.shape[1])
# Out:
# Feature matrix shape: (3066766, 518)
# Number of one-hot columns: 518

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()    
model.fit(X, df["duration"])

# %%
y_pred = model.predict(X)

rmse = mean_squared_error(y, y_pred, squared=False)
print("Train RMSE:", round(rmse, 2))
